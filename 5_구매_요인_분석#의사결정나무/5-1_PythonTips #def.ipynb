# %% [markdown]
# # 변수를 하나만 받는 함수 생성

# %%
# 받은 변수를 그대로 출력하는 함수
def my_function(a):
    print(a)

# %%
my_function('Hello')
# Out:
# Hello

# %%
# 변수에 100을 더해서 출력하는 함수
def hundred(x):
    print(x + 100)

# %%
y = hundred(10)
# Out:
# 110

# %%
# 함수에 Return이 없으므로, y에 아무것도 저장되지 않음
y

# %%
# 위와 같은 연산으로, 이번에는 Return을 반영
def hundred(x):
    return x + 100

# %%
hundred(10)
# Out:
# 110

# %%
y = hundred(10)

# %%
y
# Out:
# 110

# %% [markdown]
# # 변수를 두개 받는 함수 생성

# %%
def hap(x, y):
    return x + y

# %%
hap(3, 5)
# Out:
# 8

# %%
hap(10, 21)
# Out:
# 31

# %%
# 변수를 두개 넣어야하는 자리에 하나만 넣을 경우 에러 발생
hap(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ed5e1672f221> in <module>
#       1 # 변수를 두개 넣어야하는 자리에 하나만 넣을 경우 에러 발생
# ----> 2 hap(3)
#
# TypeError: hap() missing 1 required positional argument: 'y'

# %%
# = 을 넣어 디폴트 값을 미리 설정해줄 경우, 해당 변수를 넣어주지 않아도 디폴트값으로 함수가 돌아감
def hap_ten(x, y = 10):
    return x + y

# %%
hap_ten(3, 10)
# Out:
# 13

# %%
# y값을 넣지 않았음에도, 디폴트값인 10으로 반영되어 계산됨
hap_ten(3)
# Out:
# 13

# %%
# 모든 변수에 디폴트값 설정도 가능
def hap_ten(x = 20, y = 10):
    return x + y

# %%
hap_ten(3, 9)
# Out:
# 12

# %%
# 모든 변수에 디폴트값이 있는 경우, 괄호안에 아무것도 써주지 않아도 에러가 나지 않음
hap_ten()
# Out:
# 30

# %% [markdown]
# # if가 들어가는 함수 생성

# %%
def ten(x):
    if x > 10:
        print('large')
    else:
        print('small')

# %%
ten(30)
# Out:
# large

# %%
ten(5)
# Out:
# small

# %%
def plus_minus_ten(x):
    if x > 10:
        return x + 10
    else:
        return x - 10

# %%
plus_minus_ten(15)
# Out:
# 25

# %%
plus_minus_ten(3)
# Out:
# -7

# %% [markdown]
# # DataFrame에 함수 적용해보기

# %%
import pandas as pd

# %%
data = pd.read_csv('galaxy.csv')

# %%
data.head()
# Out:
#    BuyItNow  startprice carrier       color   productline  \
# 0         0      199.99    None       White     Galaxy_S9
# 1         0      235.00    None         NaN  Galaxy_Note9
# 2         0      199.99     NaN         NaN       Unknown
# 3         1      175.00    AT&T  Space Gray  Galaxy_Note9
# 4         1      100.00    None  Space Gray     Galaxy_S8
#
#           noDescription  charCountDescription  upperCaseDescription  sold
# 0  contains description                     0                     0     1
# 1  contains description                     0                     0     0
# 2        no description                   100                     2     0
# 3  contains description                     0                     0     1
# 4  contains description                     0                     0     1

# %%
# startprice 가 .99 로 끝나는 경우는 0.01을 더해주고 100을 곱하며, .00으로 끝날경우는 그냥 100을 곱하는 함수 생성

def price(x):
    if x % 1 == 0:
        return x * 100
    else:
        return (x + 0.01) * 100

# %%
price(99.99)
# Out:
# 10000.0

# %%
# 판다스 시리즈 혹은 데이터 프레임을 바로 함수안에 넣으면, 하나의 숫자가 입력된게 아니므로 에러 발생
price(data['startprice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-b417a77849f6> in <module>
#       1 # 판다스 시리즈 혹은 데이터 프레임을 바로 함수안에 넣으면, 하나의 숫자가 입력된게 아니므로 에러 발생
# ----> 2 price(data['startprice'])
#
# <ipython-input-29-4f6d37a7d9e0> in price(x)
#       2
#       3 def price(x):
# ----> 4     if x % 1 == 0:
#       5         return x * 100
#       6     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# apply와 lambda를 활용하여, 판다스 시리즈 안의 데이터를 하나하나씩 함수에 적용

data['startprice'].apply(lambda a: price(a))
# Out:
# 0       20000.0
# 1       23500.0
# 2       20000.0
# 3       17500.0
# 4       10000.0
#          ...
# 1480     8951.0
# 1481    23996.0
# 1482    33000.0
# 1483     8900.0
# 1484    12000.0
# Name: startprice, Length: 1485, dtype: float64

# %%
# 데이터프레임도 같은 방식으로 적용 가능 (axis 주의)
data.apply(lambda x: price(x['startprice']), axis = 1)
# Out:
# 0       20000.0
# 1       23500.0
# 2       20000.0
# 3       17500.0
# 4       10000.0
#          ...
# 1480     8951.0
# 1481    23996.0
# 1482    33000.0
# 1483     8900.0
# 1484    12000.0
# Length: 1485, dtype: float64

# %% [markdown]
# # apply와 lambda를 활용하여, def 없이 한줄에 간단한 함수 작성

# %%
def name(x):
    if x > 10:
        return x + 10 
    else:
        return x - 10

# %%
data['startprice'].apply(lambda x: name(x))
# Out:
# 0       209.99
# 1       245.00
# 2       209.99
# 3       185.00
# 4       110.00
#          ...
# 1480     99.50
# 1481    249.95
# 1482    339.99
# 1483     99.00
# 1484    129.99
# Name: startprice, Length: 1485, dtype: float64

# %%
# 위의 name 펑션과 정확하게 동일한 함수를 한줄로 작성

data['startprice'].apply(lambda x: x+10 if x > 10 else x - 10)
# Out:
# 0       209.99
# 1       245.00
# 2       209.99
# 3       185.00
# 4       110.00
#          ...
# 1480     99.50
# 1481    249.95
# 1482    339.99
# 1483     99.00
# 1484    129.99
# Name: startprice, Length: 1485, dtype: float64

# %%
def price(x):
    if x % 1 == 0:
        return x * 100
    else:
        return (x + 0.01) * 100

# %%
# 위의 price 펑션과 정확하게 동일한 함수를 한줄로 작성
data['startprice'].apply(lambda x: x * 100 if x % 1 == 0 else (x + 0.01) * 100)
# Out:
# 0       20000.0
# 1       23500.0
# 2       20000.0
# 3       17500.0
# 4       10000.0
#          ...
# 1480     8951.0
# 1481    23996.0
# 1482    33000.0
# 1483     8900.0
# 1484    12000.0
# Name: startprice, Length: 1485, dtype: float64

# %%
data['startprice']
# Out:
# 0       199.99
# 1       235.00
# 2       199.99
# 3       175.00
# 4       100.00
#          ...
# 1480     89.50
# 1481    239.95
# 1482    329.99
# 1483     89.00
# 1484    119.99
# Name: startprice, Length: 1485, dtype: float64

# %%
# elif는 괄호를 활용하여 if를 2번 적용시켜서 활용
data['startprice'].apply(lambda x: 200 if x > 200 else (100 if x > 100 else 0))
# Out:
# 0       100
# 1       200
# 2       100
# 3       100
# 4         0
#        ...
# 1480      0
# 1481    200
# 1482    200
# 1483      0
# 1484    100
# Name: startprice, Length: 1485, dtype: int64
